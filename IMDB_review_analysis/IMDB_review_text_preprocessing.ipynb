# %% [markdown]
# <div style="background-color: #4b3832; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
#   <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Text Data Preprocessing of IMDB Review
# </h1>
# </div>

# %% [markdown]
# # Data Collection

# %%
with open('IMDB_review.txt', 'r') as file:
    text = file.read()
print(text)
# Out:
# This is a very strange film that was long thought to be forgotten. It's the story of two American Army buddies, William Boyd (aka "Hopalong Cassidy") and Louis Wolheim, and their adventures as they manage to escape from a German prison camp during WWI. However, as this is a comedy, the duo manage to make the most round about and stupid escape--accidentally boarding a train to Constantinople to be placed in a Turkish prisoner of war camp! On the way, they manage to escape once again and end up in quite the adventure--meeting sexy Mary Astor along the way.As far as the film goes, it was a rather funny script and despite being a silly plot, it worked rather well. The chemistry between Boyd and Wolheim worked and the film managed to be quite entertaining. Oddly, however, the film managed to beat out Harold Lloyd's film, SPEEDY, for an Oscar for Best Direction for a Comedy (a category no longer used)--as SPEEDY was a superior film in most ways (it's one of Lloyd's best films). Still, it's
# ...

# %% [markdown]
# # Tokenization

# %%
import nltk
from nltk.tokenize import word_tokenize
with open('IMDB_review.txt', 'r') as file:
    text = file.read()
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'very', 'strange', 'film', 'that', 'was', 'long', 'thought', 'to', 'be', 'forgotten', '.', 'It', "'s", 'the', 'story', 'of', 'two', 'American', 'Army', 'buddies', ',', 'William', 'Boyd', '(', 'aka', '``', 'Hopalong', 'Cassidy', "''", ')', 'and', 'Louis', 'Wolheim', ',', 'and', 'their', 'adventures', 'as', 'they', 'manage', 'to', 'escape', 'from', 'a', 'German', 'prison', 'camp', 'during', 'WWI', '.', 'However', ',', 'as', 'this', 'is', 'a', 'comedy', ',', 'the', 'duo', 'manage', 'to', 'make', 'the', 'most', 'round', 'about', 'and', 'stupid', 'escape', '--', 'accidentally', 'boarding', 'a', 'train', 'to', 'Constantinople', 'to', 'be', 'placed', 'in', 'a', 'Turkish', 'prisoner', 'of', 'war', 'camp', '!', 'On', 'the', 'way', ',', 'they', 'manage', 'to', 'escape', 'once', 'again', 'and', 'end', 'up', 'in', 'quite', 'the', 'adventure', '--', 'meeting', 'sexy', 'Mary', 'Astor', 'along', 'the', 'way.As', 'far', 'as', 'the', 'film', 'goes', ',', 'it', 'was', 'a', 'rather'
# ...

# %% [markdown]
# # Token Filtering

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

print(filtered_tokens)
# Out:
# ['strange', 'film', 'long', 'thought', 'forgotten', '.', "'s", 'story', 'two', 'American', 'Army', 'buddies', ',', 'William', 'Boyd', '(', 'aka', '``', 'Hopalong', 'Cassidy', "''", ')', 'Louis', 'Wolheim', ',', 'adventures', 'manage', 'escape', 'German', 'prison', 'camp', 'WWI', '.', 'However', ',', 'comedy', ',', 'duo', 'manage', 'make', 'round', 'stupid', 'escape', '--', 'accidentally', 'boarding', 'train', 'Constantinople', 'placed', 'Turkish', 'prisoner', 'war', 'camp', '!', 'way', ',', 'manage', 'escape', 'end', 'quite', 'adventure', '--', 'meeting', 'sexy', 'Mary', 'Astor', 'along', 'way.As', 'far', 'film', 'goes', ',', 'rather', 'funny', 'script', 'despite', 'silly', 'plot', ',', 'worked', 'rather', 'well', '.', 'chemistry', 'Boyd', 'Wolheim', 'worked', 'film', 'managed', 'quite', 'entertaining', '.', 'Oddly', ',', 'however', ',', 'film', 'managed', 'beat', 'Harold', 'Lloyd', "'s", 'film', ',', 'SPEEDY', ',', 'Oscar', 'Best', 'Direction', 'Comedy', '(', 'category', 'longer', '
# ...

# %% [markdown]
# # Lemmatization

# %%
import nltk
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

print(lemmatized_tokens)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Kowstubha\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ...

# %% [markdown]
# # Sentiment Analysis

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
with open('IMDB_review.txt', 'r') as file:
    text = file.read()
analyzer = SentimentIntensityAnalyzer()

sentiment_scores = analyzer.polarity_scores(text)
print(sentiment_scores)
# Out:
# {'neg': 0.084, 'neu': 0.712, 'pos': 0.205, 'compound': 0.9834}
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Kowstubha\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # Named Entity Recognition

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import ne_chunk
with open('IMDB_review.txt', 'r') as file:
    text = file.read()
tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

pos_tags = nltk.pos_tag(lemmatized_tokens)
nltk.download('maxent_ne_chunker')
nltk.download('words')
ner_tags = ne_chunk(pos_tags)

print(ner_tags)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Kowstubha\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Kowstubha\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   strange/JJ
#   film/NN
#   long/RB
#   thought/VBD
#   forgotten/RB
#   ./.
#   's/POS
#   story/NN
#   two/CD
#   (ORGANIZATION American/JJ Army/NNP)
#   buddy/NN
#   ,/,
#   (PERSON William/NNP Boyd/NNP)
#   (/(
#   aka/IN
#   ``/``
#   (PERSON Hopalong/NNP Cassidy/NNP)
#   ''/''
#   )/)
#   (PERSON Louis/NNP Wolheim/NNP)
#   ,/,
#   adventure/NN
#   manage/NN
#   escape/JJ
#   (GPE German/NNP)
#   prison/NN
#   camp/NN
#   (ORGANIZATION WWI/NNP)
#   ./.
#   However/RB
#   ,/,
#   comedy/NN
#   ,/,
#   duo/JJ
#   manage/NN
#   make/VBP
#   round/NN
#   stupid/JJ
#   escape/NN
#   --/:
#   accidentally/RB
#   boarding/VBG
# ...

# %% [markdown]
# #  Word Frequency Analysis

# %%
from collections import Counter
word_counts = Counter(tokens)
top_10_words = word_counts.most_common(10)
print("Top 10 Most Frequent Words:")
for word, freq in top_10_words:
    print(f"{word}: {freq}")
# Out:
# Top 10 Most Frequent Words:
# a: 14
# ,: 14
# the: 11
# to: 8
# and: 8
# film: 7
# .: 6
# 's: 5
# --: 5
# as: 4

# %% [markdown]
# # Word Cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.show()
